# %%
import pandas as pd

data=pd.read_csv('iris.csv')
data
a=data.head(n=14)
b=data.info()
print("info is",b)
c=data.shape
print(c)
d=data.describe()
print(d)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# info is None
# (150, 6)
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# ...

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
print(data.groupby("Species").size())
print(data.groupby("Species").min())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %%
data=data.drop(columns="Id")

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data=data[data["Species"]=="Iris-setosa"]

# %%
data
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
#histogram
from matplotlib import pyplot as plt

data=data["SepalWidthCm"]
data.plot(kind="hist", label="sentosa",color='r',fontsize=10)
plt.title("sepal-widthcm")
plt.show()

# %%
from matplotlib import pyplot as plt
data=data[data["Species"]=="Iris-setosa"]
data.plot(x="SepalLengthCm",y="SepalWidthCm",kind="scatter",label='data',color='b')
plt.title('scatter plot')
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
plt.show()

# %%
from matplotlib import pyplot as plt
data=data[data["Species"]=="Iris-setosa"]
data.plot(y="SepalWidthCm",kind="line",label='data',color='b')
plt.title('scatter plot')
plt.ylabel("SepalWidthCm")
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data=pd.read_csv('iris.csv')
data['SepalWidthCm'].plot(kind="line", color="pink",linewidth='1.5',ls=':',legend='sentosa')
plt.axis([150,120,2,5])
plt.title("line plot")
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
from matplotlib import pyplot as plt
sentosa=data[data["Species"]=="Iris-setosa"]
versicolor=data[data["Species"]=="Iris-versicolor"]
virginica=data[data["Species"]=="Iris-virginica"]
sentosa['SepalWidthCm'].plot(y="SepalWidthCm",kind="line",label='data',color='black')
versicolor['SepalWidthCm'].plot(y="SepalWidthCm",kind="line",label='data',color='blue')
virginica['SepalWidthCm'].plot(y="SepalWidthCm",kind="line",label='data',color='red')
plt.title('scatter plot')
plt.ylabel("SepalWidthCm")
plt.show()

# %%
sentosa.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
from matplotlib import pyplot as plt

sentosa.plot.area(stacked='False')
plt.show()

# %%
Type=list(data['Species'].unique())
count=list(data['Species'].value_counts())
Avg=list(data.groupby('Species')["SepalLengthCm"].mean())
#plt.bar(Type,Avg,color=['red','blue','green','pink'],width=0.4)
#for horizontal bar bar to barh and take height
plt.barh(Type,Avg,color=['red','blue','green','pink'], height=0.4)
# Out:
# <BarContainer object of 3 artists>

# %%
e=(0,0.1,0)
Avg=list(data.groupby('Species')["SepalLengthCm"].mean())
plt.pie(Avg,explode=e,labels=['sentosa','versicolor','virginica'])
plt.title('pie chart')
plt.legend(title="iris-flowers")
plt.show()

# %%
data=pd.read_csv('iris.csv')
sentosa=data["SepalLengthCm"]
#sentosa.plot.box()
#to change the shape of the box
sentosa.plot.box(notch="True")
plt.title('box-plot')
plt.legend(labels=['SepalLengthcm'],title="iris-flowers")
plt.show()

# %%
import seaborn as sns
a=pd.read_csv('iris.csv')
a=a.drop(columns="Id")
sns.set(style="ticks")
#white, whitegrid,dark,darkgrid,ticks
sns.pairplot(a,hue="Species")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the CSV file into a DataFrame
data = pd.read_csv('iris.csv')

data.dropna(subset=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm'], inplace=True)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data['SepalLengthCm'], data['SepalWidthCm'], data['PetalLengthCm'],cmap="plasma" ,s=50)

ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
ax.set_zlabel('PetalLengthCm')
ax.set_title('3D Scatter Plot: SepalLengthCm, SepalWidthCm, PetalLengthCm')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



data = pd.read_csv('iris.csv')

data.dropna(subset=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], inplace=True)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot_trisurf(data['SepalLengthCm'], data['SepalWidthCm'], data['PetalLengthCm'], cmap='viridis', linewidth=0.2, edgecolor='k', antialiased=True)

ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
ax.set_zlabel('PetalLengthCm')
ax.set_title('3D Area Plot: SepalLengthCm, SepalWidthCm, PetalLengthCm')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

Type= list(data.groupby('Species')['SepalLengthCm'].mean())
Avg=list(data.groupby('Species')['SepalLengthCm'].mean())
fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111,projection='3d')
colors=['orange','blue','pink']
ax.bar(Type,Avg,Avg,color=colors,zdir='y',alpha=0.5)#alpha is used for transparency
ax.set_title('3D Bar Plot')
ax.set_xlabel('Species')
ax.set_ylabel('SepalWidthCm')
ax.set_zlabel("AverageSepalLengthCm")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig= plt.figure(14,19)
ax=fig.add_subplot
